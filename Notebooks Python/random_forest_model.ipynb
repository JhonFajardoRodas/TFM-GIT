# %% [markdown]
# ## Randon Forest: Modelo multivariante de Machine Learning

# %% [markdown]
# ### Probaremos modelos de predicción multivariantes, en este caso necesitamos predecir el volumen de ampliciones en función de la provincia. Necesitamos saber en qué regiones del país el volumen de trabajo será mayor para tener presencia de personal de trbajo y poder decidir mejor la ubicación de los almacenes de stock.
